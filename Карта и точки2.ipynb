# %% [markdown]
# <a href="https://colab.research.google.com/github/IlyaZutler/Project-3-Berlin-Airbnb-Ratings/blob/main/%D0%9A%D0%B0%D1%80%D1%82%D0%B0%20%D0%B8%20%D1%82%D0%BE%D1%87%D0%BA%D0%B82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# !pip install openpyxl -q
import openpyxl

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_colwidth', 1000)
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-ba87654b84ee> in <cell line: 13>()
#      11 pd.set_option('display.max_rows', 200)
#      12 pd.set_option('display.max_colwidth', 1000)
# ---> 13 warnings.filterwarnings('ignore')
#
# NameError: name 'warnings' is not defined
# Error in callback <function _draw_all_if_interactive at 0x7ad256f751b0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118     from matplotlib.image import AxesImage, FigureImage
#     119     from matplotlib.patches import FancyArrow, StepPatch, Wedge
# --> 120     from matplotlib.quiver import Barbs, Quiver, QuiverKey
#     121     from matplotlib.scale import ScaleBase
#     122     from matplotlib.transforms import Transform, Bbox
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130             if force or manager.canvas.figure.stale:
#     131                 manager.canvas.draw_idle()
# --> 132
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080             The dots per inch to save the figure in.
#    2081
# -> 2082         facecolor : :mpltype:`color` or 'auto', default: :rc:`savefig.facecolor`
#    2083             The facecolor of the figure.  If 'auto', use the current figure
#    2084             facecolor.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     392     def get_renderer(self):
#     393         w, h = self.figure.bbox.size
# --> 394         key = w, h, self.figure.dpi
#     395         reuse_renderer = (self._lastKey == key)
#     396         if not reuse_renderer:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     382     @functools.wraps(func)
#     383     def wrapper(*inner_args, **inner_kwargs):
# --> 384         if len(inner_args) <= name_idx and name not in inner_kwargs:
#     385             # Early return in the simple, non-deprecated case (much faster than
#     386             # calling bind()).
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     409         return self.renderer.tostring_rgb()
#     410
# --> 411     def tostring_argb(self):
#     412         """
#     413         Get the image as ARGB `bytes`.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      82
#      83     def __setstate__(self, state):
# ---> 84         self.__init__(state['width'], state['height'], state['dpi'])
#      85
#      86     def _update_methods(self):
#
# ValueError: Image size of 2000x67500 pixels is too large. It must be less than 2^16 in each direction.

# %%
apartments = pd.read_excel('/content/apartments.xlsx', engine='openpyxl')

# %%
apartments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23550 entries, 0 to 23549
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Listing ID               23550 non-null  int64
#  1   Listing URL              23550 non-null  object
#  2   Listing Name             23496 non-null  object
#  3   Host ID                  23550 non-null  int64
#  4   Host URL                 23550 non-null  object
#  5   Host Name                23529 non-null  object
#  6   Host Since               23529 non-null  object
#  7   Host Response Time       13059 non-null  object
#  8   Host Response Rate       13059 non-null  float64
#  9   Is Superhost             23529 non-null  object
#  10  neighbourhood            23550 non-null  object
#  11  Neighborhood Group       23550 non-null  object
#  12  City                     23547 non-null  object
#  13  Postal Code              22964 non-null  object
#  14  Country Code             23550 non-null  object
#  15  Country                  23550 non-null  object
#  16  Latitude                 23550 non-null  float64
#  17  Longitude                23550 non-null  float64
#  18  Is Exact Location        23550 non-null  object
#  19  Property Type            23550 non-null  object
#  20  Room Type                23550 non-null  object
#  21  Accomodates              23550 non-null  int64
#  22  Bathrooms                23521 non-null  float64
#  23  Bedrooms                 23530 non-null  float64
#  24  Beds                     23515 non-null  float64
#  25  Square Feet              427 non-null    float64
#  26  Price                    23550 non-null  object
#  27  Guests Included          23550 non-null  int64
#  28  Min Nights               23550 non-null  int64
#  29  Reviews                  23550 non-null  int64
#  30  First Review             19394 non-null  object
#  31  Last Review              19394 non-null  object
#  32  Overall Rating           18928 non-null  float64
#  33  Accuracy Rating          18902 non-null  float64
#  34  Cleanliness Rating       18906 non-null  float64
#  35  Checkin Rating           18884 non-null  float64
#  36  Communication Rating     18900 non-null  float64
#  37  Location Rating          18885 non-null  float64
#  38  Value Rating             18882 non-null  float64
#  39  Instant Bookable         23550 non-null  object
#  40  Business Travel Ready    23550 non-null  object
#  41  Location Rating Roughly  18885 non-null  float64
#  42  Reviews Log              23550 non-null  float64
# dtypes: float64(16), int64(6), object(21)
# memory usage: 7.7+ MB
# Error in callback <function _draw_all_if_interactive at 0x7ad256f751b0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118     from matplotlib.image import AxesImage, FigureImage
#     119     from matplotlib.patches import FancyArrow, StepPatch, Wedge
# --> 120     from matplotlib.quiver import Barbs, Quiver, QuiverKey
#     121     from matplotlib.scale import ScaleBase
#     122     from matplotlib.transforms import Transform, Bbox
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130             if force or manager.canvas.figure.stale:
#     131                 manager.canvas.draw_idle()
# --> 132
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080             The dots per inch to save the figure in.
#    2081
# -> 2082         facecolor : :mpltype:`color` or 'auto', default: :rc:`savefig.facecolor`
#    2083             The facecolor of the figure.  If 'auto', use the current figure
#    2084             facecolor.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     392     def get_renderer(self):
#     393         w, h = self.figure.bbox.size
# --> 394         key = w, h, self.figure.dpi
#     395         reuse_renderer = (self._lastKey == key)
#     396         if not reuse_renderer:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     382     @functools.wraps(func)
#     383     def wrapper(*inner_args, **inner_kwargs):
# --> 384         if len(inner_args) <= name_idx and name not in inner_kwargs:
#     385             # Early return in the simple, non-deprecated case (much faster than
#     386             # calling bind()).
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     409         return self.renderer.tostring_rgb()
#     410
# --> 411     def tostring_argb(self):
#     412         """
#     413         Get the image as ARGB `bytes`.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      82
#      83     def __setstate__(self, state):
# ---> 84         self.__init__(state['width'], state['height'], state['dpi'])
#      85
#      86     def _update_methods(self):
#
# ValueError: Image size of 2000x67500 pixels is too large. It must be less than 2^16 in each direction.

# %%
apartments.describe()
# Out:
#          Listing ID       Host ID  Host Response Rate      Latitude  \
# count  2.355000e+04  2.355000e+04        13059.000000  23550.000000
# mean   1.777983e+07  6.171756e+07            0.918446     52.509912
# std    9.888427e+06  6.781943e+07            0.194464      0.031275
# min    2.695000e+03  1.581000e+03            0.000000     52.345800
# 25%    9.054361e+06  9.811146e+06            0.950000     52.489182
# 50%    1.874644e+07  3.422998e+07            1.000000     52.509215
# 75%    2.587844e+07  9.410927e+07            1.000000     52.532670
# max    3.468232e+07  2.616142e+08            1.000000     52.651670
#
#           Longitude   Accomodates     Bathrooms      Bedrooms          Beds  \
# count  23550.000000  23550.000000  23521.000000  23530.000000  23515.000000
# mean      13.406185      2.671932      1.096021      1.161708      1.642058
# std        0.058561      1.567881      0.346164      0.660594      1.228787
# min       13.097180      1.000000      0.000000      0.000000      0.000000
# 25%       13.375730      2.000000      1.000000      1.000000      1.000000
# 50%       13.416555      2.000000      1.000000      1.000000      1.000000
# 75%       13.439510      3.000000      1.000000      1.000000      2.000000
# max       13.757640     16.000000      8.500000     10.000000     22.000000
#
#        Square Feet  Guests Included   Min Nights       Reviews  \
# count   427.000000     23550.000000  23550.00000  23550.000000
# mean    485.480094         1.346157      6.90034     19.298471
# std     517.079921         0.856122     24.87503     40.476058
# min       0.000000         1.000000      1.00000      0.000000
# 25%       0.000000         1.000000      2.00000      1.000000
# 50%     409.000000         1.000000      3.00000      5.000000
# 75%     742.500000         1.000000      4.00000     17.000000
# max    4639.000000        16.000000   1000.00000    545.000000
#
#        Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# count    18928.000000     18902.000000        18906.000000    18884.000000
# mean        94.563926         9.679981            9.335079        9.728924
# std          7.598217         0.737602            1.030974        0.695091
# min         20.000000         2.000000            2.000000        2.000000
# 25%         92.000000        10.000000            9.000000       10.000000
# 50%         97.000000        10.000000           10.000000       10.000000
# 75%        100.000000        10.000000           10.000000       10.000000
# max        100.000000        10.000000           10.000000       10.000000
#
#        Communication Rating  Location Rating  Value Rating
# count          18900.000000     18885.000000  18882.000000
# mean               9.746561         9.550384      9.417646
# std                0.679421         0.748553      0.840252
# min                2.000000         2.000000      2.000000
# 25%               10.000000         9.000000      9.000000
# 50%               10.000000        10.000000     10.000000
# 75%               10.000000        10.000000     10.000000
# max               10.000000        10.000000     10.000000

# %%
apartments.isnull().sum()
# Out:
# Listing ID                   0
# Listing URL                  0
# Listing Name                54
# Host ID                      0
# Host URL                     0
# Host Name                   21
# Host Since                  21
# Host Response Time       10491
# Host Response Rate       10491
# Is Superhost                21
# neighbourhood                0
# Neighborhood Group           0
# City                         3
# Postal Code                586
# Country Code                 0
# Country                      0
# Latitude                     0
# Longitude                    0
# Is Exact Location            0
# Property Type                0
# Room Type                    0
# Accomodates                  0
# Bathrooms                   29
# Bedrooms                    20
# Beds                        35
# Square Feet              23123
# Price                        0
# Guests Included              0
# Min Nights                   0
# Reviews                      0
# First Review              4156
# Last Review               4156
# Overall Rating            4622
# Accuracy Rating           4648
# Cleanliness Rating        4644
# Checkin Rating            4666
# Communication Rating      4650
# Location Rating           4665
# Value Rating              4668
# Instant Bookable             0
# Business Travel Ready        0
# Num_Review                   0
# dtype: int64

# %%
apartments.columns
# Out:
# Index(['Listing ID', 'Listing URL', 'Listing Name', 'Host ID', 'Host URL',
#        'Host Name', 'Host Since', 'Host Response Time', 'Host Response Rate',
#        'Is Superhost', 'neighbourhood', 'Neighborhood Group', 'City',
#        'Postal Code', 'Country Code', 'Country', 'Latitude', 'Longitude',
#        'Is Exact Location', 'Property Type', 'Room Type', 'Accomodates',
#        'Bathrooms', 'Bedrooms', 'Beds', 'Square Feet', 'Price',
#        'Guests Included', 'Min Nights', 'Reviews', 'First Review',
#        'Last Review', 'Overall Rating', 'Accuracy Rating',
#        'Cleanliness Rating', 'Checkin Rating', 'Communication Rating',
#        'Location Rating', 'Value Rating', 'Instant Bookable',
#        'Business Travel Ready'],
#       dtype='object')

# %%
apartments_numeric = apartments[['Accomodates',
       'Bathrooms', 'Bedrooms', 'Beds', 'Square Feet', 'Price',
       'Guests Included', 'Min Nights', 'Reviews', 'First Review',
       'Last Review', 'Overall Rating', 'Accuracy Rating',
       'Cleanliness Rating', 'Checkin Rating', 'Communication Rating',
       'Location Rating', 'Value Rating']]

# %%
 21  Accomodates              23550 non-null  int64
 22  Bathrooms                23521 non-null  float64
 23  Bedrooms                 23530 non-null  float64
 24  Beds                     23515 non-null  float64
 25  Square Feet              427 non-null    float64
 26  Price                    23550 non-null  object
 27  Guests Included          23550 non-null  int64
 28  Min Nights               23550 non-null  int64
 29  Reviews                  23550 non-null  int64
 30  First Review             19394 non-null  object
 31  Last Review              19394 non-null  object
 32  Overall Rating           18928 non-null  float64
 33  Accuracy Rating          18902 non-null  float64
 34  Cleanliness Rating       18906 non-null  float64
 35  Checkin Rating           18884 non-null  float64
 36  Communication Rating     18900 non-null  float64
 37  Location Rating          18885 non-null  float64
 38  Value Rating             18882 non-null  float64
 39  Instant Bookable         23550 non-null  object
 40  Business Travel Ready    23550 non-null  object
 41  Location Rating Roughly  18885 non-null  float64
 42  Reviews Log              23550 non-null  float64

# %% [markdown]
# **This dataset contains information on Airbnb listings in Berlin, including reviewer ratings and comments**
#
# review_date: The date of the review. (Date)
#
#
# Reviewer Name: The name of the reviewer. (String)
#
#
# Comments: The reviewer's comments. (String)
#
#
# Listing URL: The URL of the listing. (String)
#
#
# Listing Name: The name of the listing. (String)
#
#
# Host URL: The URL of the host. (String)
#
#
# Host Name: The name of the host. (String)
#
#
# Host Since: The date the host joined Airbnb. (Date)
#
#
# Host Response Time: The host's response time. (String)
#
#
# Host Response Rate: The host's response rate. (String)
#
#
# Is Superhost: Whether or not the host is a Superhost. (Boolean)
#
#
# neighbourhood: The neighbourhood of the listing. (String)
#
#
# Neighborhood Group: The neighbourhood group of the listing. (String)
#
#
# City: The city of the listing. (String)
#
#
# Postal Code: The postal code of the listing. (String)
#
#
# Country Code: The country code of the listing. (String)
#
#
# Country Code: The country code of the listing. (String)
#
#
# Latitude: The latitude of the listing. (Float)
#
#
# Longitude: The longitude of the listing. (Float)
#
#
# Is Exact Location: Whether or not the location is exact. (Boolean)
#
#
# Property Type: The type of property. (String)
#
#
# Room Type: The type of room. (String)
#
#
# Accomodates: The number of people the property can accommodate. (Integer)
#
#
# Bathrooms: The number of bathrooms. (Float)
#
#
# Bedrooms: The number of bedrooms. (Integer)
#
#
# Beds: The number of beds. (Integer)
#
#
# Square Feet: The square footage of the property. (Float)
#
#
# Price: The price of the listing. (Float)
#
#
# Guests Included: The number of guests included in the price. (Integer)
#
#
# Min Nights: The minimum number of nights required to stay. (Integer)
#
#
# Reviews: The number of reviews the listing has. (Integer)
#
#
# First Review: The date of the first review. (Date)
#
#
# Last Review: The date of the last review. (Date)
#
#
# Overall Rating: The listing's overall rating. (Float)
#
#
# Accuracy Rating: The listing's accuracy rating. (Float)
#
#
# Cleanliness Rating: The listing's cleanliness rating. (Float)
#
#
# Checkin Rating: The listing's checkin rating. (Float)
#
#
# Communication Rating: The listing's communication rating. (Float)
#
#
# Location Rating: The listing's location rating. (Float)
#
#
# Value Rating: The listing's value rating. (Float)

# %%
# !pip install autoviz -q
from autoviz.AutoViz_Class import AutoViz_Class
# %matplotlib inline
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
AV = AutoViz_Class()
# Use AutoViz with DataFrame
AV.AutoViz('', dfte=apartments)
# Out:
# Shape of your Data Set loaded: (23550, 43)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  15
#     Number of Integer-Categorical Columns =  6
#     Number of String-Categorical Columns =  9
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  2
#     Number of NLP String Columns =  6
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  2
#     43 Predictors classified...
#         2 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Square Feet', 'Business Travel Ready']
# 15 numeric variables in data exceeds limit, taking top 30 variables
#     List of variables selected: ['Host Response Rate', 'Latitude', 'Longitude', 'Bathrooms', 'Beds', 'Overall Rating', 'Reviews Log', 'Bedrooms', 'Accuracy Rating', 'Cleanliness Rating', 'Checkin Rating', 'Communication Rating', 'Location Rating', 'Value Rating', 'Location Rating Roughly']
#    Total columns > 30, too numerous to print.
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_5e924_row0_col0, #T_5e924_row0_col2, #T_5e924_row0_col3, #T_5e924_row0_col4, #T_5e924_row0_col5, #T_5e924_row1_col0, #T_5e924_row1_col2, #T_5e924_row1_col3, #T_5e924_row1_col4, #T_5e924_row1_col5, #T_5e924_row2_col0, #T_5e924_row2_col2, #T_5e924_row2_col3, #T_5e924_row2_col4, #T_5e924_row2_col5, #T_5e924_row3_col0, #T_5e924_row3_col2, #T_5e924_row3_col3, #T_5e924_row3_col4, #T_5e924_row3_col5, #T_5e924_row4_col0, #T_5e924_row4_col2, #T_5e924_row4_col3, #T_5e924_row4_col4, #T_5e924_row4_col5, #T_5e924_row5_col0, #T_5e924_row5_col2, #T_5e924_row5_col3, #T_5e924_row5_col4, #T_5e924_row5_col5, #T_5e924_row6_col0, #T_5e924_row6_col2, #T_5e924_row6_col3, #T_5e924_row6_col4, #T_5e924_row6_col5, #T_5e924_row7_col0, #T_5e924_row7_col2, #T_5e924_row7_col3, #T_5e924_row7_col4, #T_5e924_row7_col5, #T_5e924_row8_col0, #T_5e924_row8_col2, #T_5e924_row8_col3, #T_5e924_row8_col4, #T_5e924_row8_col5, #T_5e924_row9_col0, #T_5e924_row9_col2, #T_5e924_row9_col3, #T_5e924_row9_col4, #T_5e924_row9_col5, #T_5e924_row10_col0, #T_5e924_row10_col2, #T_5e924_row10_col3, #T_5e924_row10_col4, #T_5e924_row10_col5, #T_5e924_row11_col0, #T_5e924_row11_col2, #T_5e924_row11_col3, #T_5e924_row11_col4, #T_5e924_row11_col5, #T_5e924_row12_col0, #T_5e924_row12_col2, #T_5e924_row12_col3, #T_5e924_row12_col4, #T_5e924_row12_col5, #T_5e924_row13_col0, #T_5e924_row13_col2, #T_5e924_row13_col3, #T_5e924_row13_col4, #T_5e924_row13_col5, #T_5e924_row14_col0, #T_5e924_row14_col2, #T_5e924_row14_col3, #T_5e924_row14_col4, #T_5e924_row14_col5, #T_5e924_row15_col0, #T_5e924_row15_col2, #T_5e924_row15_col3, #T_5e924_row15_col4, #T_5e924_row15_col5, #T_5e924_row16_col0, #T_5e924_row16_col2, #T_5e924_row16_col3, #T_5e924_row16_col4, #T_5e924_row16_col5, #T_5e924_row17_col0, #T_5e924_row17_col2, #T_5e924_row17_col3, #T_5e924_row17_col4, #T_5e924_row17_col5, #T_5e924_row18_col0, #T_5e924_row18_col2, #T_5e924_row18_col3, #T_5e924_row18_col4, #T_5e924_row18_col5, #T_5e924_row19_col0, #T_5e924_row19_col2, #T_5e924_row19_col3, #T_5e924_row19_col4, #T_5e924_row19_col5, #T_5e924_row20_col0, #T_5e924_row20_col2, #T_5e924_row20_col3, #T_5e924_row20_col4, #T_5e924_row20_col5, #T_5e924_row21_col0, #T_5e924_row21_col2, #T_5e924_row21_col3, #T_5e924_row21_col4, #T_5e924_row21_col5, #T_5e924_row22_col0, #T_5e924_row22_col2, #T_5e924_row22_col3, #T_5e924_row22_col4, #T_5e924_row22_col5, #T_5e924_row23_col0, #T_5e924_row23_col2, #T_5e924_row23_col3, #T_5e924_row23_col4, #T_5e924_row23_col5, #T_5e924_row24_col0, #T_5e924_row24_col2, #T_5e924_row24_col3, #T_5e924_row24_col4, #T_5e924_row24_col5, #T_5e924_row25_col0, #T_5e924_row25_col2, #T_5e924_row25_col3, #T_5e924_row25_col4, #T_5e924_row25_col5, #T_5e924_row26_col0, #T_5e924_row26_col2, #T_5e924_row26_col3, #T_5e924_row26_col4, #T_5e924_row26_col5, #T_5e924_row27_col0, #T_5e924_row27_col2, #T_5e924_row27_col3, #T_5e924_row27_col4, #T_5e924_row27_col5, #T_5e924_row28_col0, #T_5e924_row28_col2, #T_5e924_row28_col3, #T_5e924_row28_col4, #T_5e924_row28_col5, #T_5e924_row29_col0, #T_5e924_row29_col2, #T_5e924_row29_col3, #T_5e924_row29_col4, #T_5e924_row29_col5, #T_5e924_row30_col0, #T_5e924_row30_col2, #T_5e924_row30_col3, #T_5e924_row30_col4, #T_5e924_row30_col5, #T_5e924_row31_col0, #T_5e924_row31_col2, #T_5e924_row31_col3, #T_5e924_row31_col4, #T_5e924_row31_col5, #T_5e924_row32_col0, #T_5e924_row32_col2, #T_5e924_row32_col3, #T_5e924_row32_col4, #T_5e924_row32_col5, #T_5e924_row33_col0, #T_5e924_row33_col2, #T_5e924_row33_col3, #T_5e924_row33_col4, #T_5e924_row33_col5, #T_5e924_row34_col0, #T_5e924_row34_col2, #T_5e924_row34_col3, #T_5e924_row34_col4, #T_5e924_row34_col5, #T_5e924_row35_col0, #T_5e924_row35_col2, #T_5e924_row35_col3, #T_5e924_row35_col4, #T_5e924_row35_col5, #T_5e924_row36_col0, #T_5e924_row36_col2, #T_5e924_row36_col3, #T_5e924_row36_col4, #T_5e924_row36_col5, #T_5e924_row37_col0, #T_5e924_row37_col2, #T_5e924_row37_col3, #T_5e924_row37_col4, #T_5e924_row37_col5, #T_5e924_row38_col0, #T_5e924_row38_col2, #T_5e924_row38_col ...
#   font-family: Segoe UI;
# }
# #T_5e924_row0_col1, #T_5e924_row1_col1, #T_5e924_row2_col1, #T_5e924_row3_col1, #T_5e924_row4_col1, #T_5e924_row5_col1, #T_5e924_row6_col1, #T_5e924_row9_col1, #T_5e924_row10_col1, #T_5e924_row11_col1, #T_5e924_row12_col1, #T_5e924_row14_col1, #T_5e924_row15_col1, #T_5e924_row16_col1, #T_5e924_row17_col1, #T_5e924_row18_col1, #T_5e924_row19_col1, #T_5e924_row20_col1, #T_5e924_row21_col1, #T_5e924_row22_col1, #T_5e924_row23_col1, #T_5e924_row24_col1, #T_5e924_row26_col1, #T_5e924_row27_col1, #T_5e924_row28_col1, #T_5e924_row29_col1, #T_5e924_row39_col1, #T_5e924_row40_col1, #T_5e924_row42_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_5e924_row7_col1, #T_5e924_row8_col1 {
#   background-color: #fb7858;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_5e924_row13_col1 {
#   background-color: #fff1ea;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_5e924_row25_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_5e924_row30_col1, #T_5e924_row31_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_5e924_row32_col1, #T_5e924_row33_col1, #T_5e924_row34_col1, #T_5e924_row35_col1, #T_5e924_row36_col1, #T_5e924_row37_col1, #T_5e924_row38_col1, #T_5e924_row41_col1 {
#   background-color: #fdcab5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_5e924" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e924_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_5e924_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_5e924_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_5e924_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_5e924_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_5e924_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e924_level0_row0" class="row_heading level0 row0" >Listing ID</th>
#       <td id="T_5e924_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_5e924_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_5e924_row0_col2" class="data row0 col2" >99</td>
#       <td id="T_5e924_row0_col3" class="data row0 col3" >2695.000000</td>
#       <td id="T_5e924_row0_col4" class="data row0 col4" >34682315.000000</td>
#       <td id="T_5e924_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_5e924_level0_row1" class="row_heading level0 row1" >Listing URL</th>
#       <td id="T_5e924_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_5e924_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_5e924_row1_col2" class="data row1 col2" >99</td>
#       <td id="T_5e924_row1_col3" class="data row1 col3" ></td>
#       <td id="T_5e924_row1_col4" class="data row1 col4" ></td>
#       <td id="T_5e924_row1_col5" class="data row1 col5" >23536 rare categories: Too many to list. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_5e924_level0_row2" class="row_heading level0 row2" >Listing Name</th>
#       <td id="T_5e924_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_5e924_row2_col1" class="data row2 col1" >0.229299</td>
#       <td id="T_5e924_row2_col2" class="data row2 col2" >96</td>
#       <td id="T_5e924_row2_col3" class="data row2 col3"
# Number of All Scatter Plots = 120
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# Could not draw wordcloud plot for Price. We need at least 1 word to plot a word cloud, got 0.
# All Plots done
# Time to run AutoViz = 132 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
#        Listing ID              Listing URL                \
# 0       10002699   https://www.airbnb.com/rooms/10002699
# 1       10002922   https://www.airbnb.com/rooms/10002922
# 2       10006647   https://www.airbnb.com/rooms/10006647
# 3       10006747   https://www.airbnb.com/rooms/10006747
# 4       10007526   https://www.airbnb.com/rooms/10007526
# ...           ...                                    ...
# 23545    9991497    https://www.airbnb.com/rooms/9991497
# 23546    9993168    https://www.airbnb.com/rooms/9993168
# 23547    9994644    https://www.airbnb.com/rooms/9994644
# 23548     999465     https://www.airbnb.com/rooms/999465
# 23549    9996186    https://www.airbnb.com/rooms/9996186
#
#                    Listing Name                Host ID  \
# 0            Trendy and peaceful KreuzkÃ¶lln  44696672
# 1            Sehr zentrale Wohnung in Berlin  45848709
# 2                Very central and very quite  40791092
# 3             Altbauwohnung in Berlin-Pankow  51401040
# 4          Mauerblick: Kreuzberg meets Mitte   8344366
# ...                                      ...       ...
# 23545   Chillout-Oase fÃ¼r "GroÃ und Klein"  44816934
# 23546  GemÃ¼tliches Zimmer zur Ãbernachtung  40660291
# 23547      Potsdamer Platz-Top Spot Studio 1  22276081
# 23548           Familyhome for your vacation   5494219
# 23549    Very nice apartment, central, Mitte  51352517
#
#                         Host URL                  Host Name Host Since  \
# 0      https://www.airbnb.com/users/show/44696672      Josh  09-20-15
# 1      https://www.airbnb.com/users/show/45848709   Belinda  10-05-15
# 2      https://www.airbnb.com/users/show/40791092   Arkadij  08-07-15
# 3      https://www.airbnb.com/users/show/51401040    Esther  12-15-15
# 4       https://www.airbnb.com/users/show/8344366      Kian  08-23-13
# ...                                           ...       ...        ...
# 23545  https://www.airbnb.com/users/show/44816934      Luca  09-22-15
# 23546  https://www.airbnb.com/users/show/40660291       Anh  08-06-15
# 23547  https://www.airbnb.com/users/show/22276081    Martin  10-08-14
# 23548   https://www.airbnb.com/users/show/5494219    Simone  03-17-13
# 23549  https://www.airbnb.com/users/show/51352517  Isabella  12-14-15
#
#        Host Response Time  Host Response Rate Is Superhost  \
# 0                     NaN          NaN              f
# 1                     NaN          NaN              f
# 2      within a few hours          1.0              f
# 3                     NaN          NaN              f
# 4                     NaN          NaN              f
# ...                   ...                 ...          ...
# 23545                 NaN          NaN              f
# 23546                 NaN          NaN              f
# 23547      within an hour          1.0              t
# 23548                 NaN          NaN              f
# 23549  within a few hours          1.0              f
#
#          neighbourhood        Neighborhood Group      City  Postal Code  \
# 0               NeukÃ¶lln                 NeukÃ¶lln  Berlin    12047.0
# 1         Prenzlauer Berg                    Pankow  Berlin    10405.0
# 2                   Mitte                     Mitte  Berlin    10178.0
# 3                  Pankow                    Pankow  Berlin    13189.0
# 4         Potsdamer Platz  Friedrichshain-Kreuzberg  Berlin    10963.0
# ...                   ...                       ...     ...         ...
# 23545  NiederschÃ¶neweide       Treptow - KÃ¶penick  Berlin        NaN
# 23546         Rummelsburg               Lichtenberg  Berlin        NaN
# 23547           Kreuzberg  Friedrichshain-Kreuzberg  Berlin    10963.0
# 23548      Friedrichshain  Friedrichshain-Kreuzberg  Berlin    10245.0
# 23549             Wedding                     Mitte  Berlin    13355.0
#
#       Country Code Country   Latitude  Longitude Is Exact Location  \
# 0          DE       Germany  52.49234  13.42994           t
# 1          DE       Germany  52.53292  13.41502           f
# 2          DE       Germany  52.52134  13.41866           t
# 3          DE       Germany  52.56552  13.41189           t
# 4          DE       Germany  52.50585  13.38580           t
# ...            ...      ...       ...        ...               ...
# 23545      DE       Germany  52.45494  13.51423           f
# 23546      DE       Germany  52.50099  13.49185           f
# 23547      DE       Germany  52.50283  13.37799           t
# 23548      DE       Germany  52.51001  13.45366           f
# 23549      DE       Germany  52.53806  13.38776           t
#
#       Property Type    Room Type      Accomodates  Bathrooms  Bedrooms  Beds  \
# 0        Apartment   Entire home/apt       4          1.0        2.0     2.0
# 1        Apartment   Entire home/apt       2          1.0        1.0     1.0
# 2        Apartment      Private room       2          1.0        1.0     1.0
# 3        Apartment   Entire home/apt       3          1.0        1.0     2.0
# 4        Apartment      Private room       4          1.0        1.0     2.0
# ...             ...              ...          ...        ...       ...   ...
# 23545    Apartment   Entire home/apt       6          1.0        2.0     2.0
# 23546    Apartment      Private room       2          1.0        1.0     1.0
# 23547    Apartment   Entire home/apt       4          1.0        1.0     3.0
# 23548    Apartment   Entire home/apt       9          1.5        4.0     6.0
# 23549    Apartment   Entire home/apt       2          2.0        1.0     1.0
#
#        Square Feet  Price   Guests Included  Min Nights  Reviews First Review  \
# 0          NaN        60.0         1              1          1     01-03-16
# 1          NaN        52.0         1              1          0          NaN
# 2          NaN        35.0         1              1         20     01-03-16
# 3          NaN        30.0         1              4          2     12-28-15
# 4          NaN        30.0         1              3          3     01-01-16
# ...            ...     ...              ...         ...      ...          ...
# 23545      NaN       50.00         1              1          3     07-05-16
# 23546      NaN       20.00         1              1         20     05-21-16
# 23547      NaN       60.00         2              1        349     01-07-16
# 23548      0.0      150.00         8              7          4     10-06-14
# 23549      NaN       80.00         2              6          3     07-27-16
#
#       Last Review  Overall Rating  Accuracy Rating  Cleanliness Rating  \
# 0       01-03-16        100.0            8.0               10.0
# 1            NaN          NaN            NaN                NaN
# 2       02-12-17         92.0            9.0                8.0
# 3       01-06-16         90.0           10.0                9.0
# 4       03-30-16        100.0           10.0                9.0
# ...           ...             ...              ...                 ...
# 23545   07-05-16          NaN            NaN                NaN
# 23546   09-18-16         92.0           10.0               10.0
# 23547   04-28-19         98.0           10.0               10.0
# 23548   08-29-15        100.0           10.0               10.0
# 23549   04-22-19         80.0           10.0                9.0
#
#        Checkin Rating  Communication Rating  Location Rating  Value Rating  \
# 0            6.0               10.0               10.0            10.0
# 1            NaN                NaN                NaN             NaN
# 2            9.0               10.0               10.0             9.0
# 3            9.0                8.0                9.0             9.0
# 4           10.0               10.0                9.0             9.0
# ...               ...                   ...              ...           ...
# 23545        NaN                NaN                NaN             NaN
# 23546       10.0                9.0                9.0             9.0
# 23547       10.0               10.0               10.0            10.0
# 23548       10.0               10.0               10.0            10.0
# 23549       10.0               10.0                9.0             9.0
#
#       Instant Bookable Business Travel Ready  Location Rating Roughly  \
# 0             f                   f                    10.0
# 1             f                   f                     NaN
# 2             f                   f                    10.0
# 3             f                   f                     9.0
# 4             t                   f                     9.0
# ...                ...                   ...                      ...
# 23545         f                   f                     NaN
# 23546         f                   f                     9.0
# 23547         t                   f                    10.0
# 23548         f                   f                    10.0
# 23549         f                   f                     9.0
#
#        Reviews Log
# 0       0.693147
# 1       0.000000
# 2       3.044522
# 3       1.098612
# 4       1.386294
# ...            ...
# 23545   1.386294
# 23546   3.044522
# 23547   5.857933
# 23548   1.609438
# 23549   1.386294
#
# [23550 rows x 43 columns]
# Error in callback <function _draw_all_if_interactive at 0x7ad256f751b0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118     from matplotlib.image import AxesImage, FigureImage
#     119     from matplotlib.patches import FancyArrow, StepPatch, Wedge
# --> 120     from matplotlib.quiver import Barbs, Quiver, QuiverKey
#     121     from matplotlib.scale import ScaleBase
#     122     from matplotlib.transforms import Transform, Bbox
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130             if force or manager.canvas.figure.stale:
#     131                 manager.canvas.draw_idle()
# --> 132
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080             The dots per inch to save the figure in.
#    2081
# -> 2082         facecolor : :mpltype:`color` or 'auto', default: :rc:`savefig.facecolor`
#    2083             The facecolor of the figure.  If 'auto', use the current figure
#    2084             facecolor.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     392     def get_renderer(self):
#     393         w, h = self.figure.bbox.size
# --> 394         key = w, h, self.figure.dpi
#     395         reuse_renderer = (self._lastKey == key)
#     396         if not reuse_renderer:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     382     @functools.wraps(func)
#     383     def wrapper(*inner_args, **inner_kwargs):
# --> 384         if len(inner_args) <= name_idx and name not in inner_kwargs:
#     385             # Early return in the simple, non-deprecated case (much faster than
#     386             # calling bind()).
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     409         return self.renderer.tostring_rgb()
#     410
# --> 411     def tostring_argb(self):
#     412         """
#     413         Get the image as ARGB `bytes`.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      82
#      83     def __setstate__(self, state):
# ---> 84         self.__init__(state['width'], state['height'], state['dpi'])
#      85
#      86     def _update_methods(self):
#
# ValueError: Image size of 2000x67500 pixels is too large. It must be less than 2^16 in each direction.

# %%
sns.histplot(apartments['Reviews'], bins=100)
plt.show()

# %%
apartments['Reviews Log'] = np.log1p(apartments['Reviews'])

# %%
sns.histplot(apartments['Reviews Log'], discrete=(True))
plt.show()

# %%
sns.histplot(apartments['Location Rating'], discrete=(True))
plt.show()

# %%
apartments['Location Rating Roughly'] = apartments['Location Rating'].apply(lambda x: 8 if x < 9 else x)

# %%
sns.histplot(apartments['Location Rating Roughly'], discrete=(True))
plt.show()

# %%
sns.histplot(apartments['Overall Rating'], discrete=(True))
plt.show()

# %%
# !pip install -q folium matplotlib

import folium
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap, Normalize, to_hex
